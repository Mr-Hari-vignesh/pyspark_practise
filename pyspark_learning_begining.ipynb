# %% [markdown]
# Creating Pyspark Session

# %%
import pyspark
from pyspark.sql import SparkSession

# creating a spark session
spark = SparkSession.builder.appName("pyspark practice").getOrCreate()

display(spark)
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=8687747474966386#setting/sparkui/0313-190753-gzhmricf/driver-4559748370044094271">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*, 4]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# %fs
ls /mnt/tf-abfss/data/ds/pyspark/bmw.csv
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/tf-abfss/data/ds/pyspark/bmw.csv</td><td>bmw.csv</td><td>592722</td></tr></tbody></table></div>

# %% [markdown]
# Reading a csv file

# %%
csv_file = '/mnt/tf-abfss/data/ds/pyspark/bmw.csv'
df = spark.read.csv(csv_file)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# displaying the dataframe without header is true
display(df.show(5))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+----+-----+------------+-------+--------+---+----+----------+
#       _c0| _c1|  _c2|         _c3|    _c4|     _c5|_c6| _c7|       _c8|
# +---------+----+-----+------------+-------+--------+---+----+----------+
#     model|year|price|transmission|mileage|fuelType|tax| mpg|engineSize|
#  5 Series|2014|11200|   Automatic|  67068|  Diesel|125|57.6|       2.0|
#  6 Series|2018|27000|   Automatic|  14827|  Petrol|145|42.8|       2.0|
#  5 Series|2016|16000|   Automatic|  62794|  Diesel|160|51.4|       3.0|
#  1 Series|2017|12750|   Automatic|  26676|  Diesel|145|72.4|       1.5|
# +---------+----+-----+------------+-------+--------+---+----+----------+
# only showing top 5 rows
#
# </div>

# %%
data = spark.read.option('header',True).csv('/mnt/tf-abfss/data/ds/pyspark/bmw.csv')
display(data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>model</th><th>year</th><th>price</th><th>transmission</th><th>mileage</th><th>fuelType</th><th>tax</th><th>mpg</th><th>engineSize</th></tr></thead><tbody><tr><td> 5 Series</td><td>2014</td><td>11200</td><td>Automatic</td><td>67068</td><td>Diesel</td><td>125</td><td>57.6</td><td>2.0</td></tr><tr><td> 6 Series</td><td>2018</td><td>27000</td><td>Automatic</td><td>14827</td><td>Petrol</td><td>145</td><td>42.8</td><td>2.0</td></tr><tr><td> 5 Series</td><td>2016</td><td>16000</td><td>Automatic</td><td>62794</td><td>Diesel</td><td>160</td><td>51.4</td><td>3.0</td></tr><tr><td> 1 Series</td><td>2017</td><td>12750</td><td>Automatic</td><td>26676</td><td>Diesel</td><td>145</td><td>72.4</td><td>1.5</td></tr><tr><td> 7 Series</td><td>2014</td><td>14500</td><td>Automatic</td><td>39554</td><td>Diesel</td><td>160</td><td>50.4</td><td>3.0</td></tr><tr><td> 5 Series</td><td>2016</td><td>14900</td><td>Automatic</td><td>35309</td><td>Diesel</td><td>125</td><td>60.1</td><td>2.0</td></tr><tr><td> 5 Series</td><td>2017</td><td>16000</td><td>Automatic</td><td>38538</td><td>Diesel</td><td>125</td><td>60.1</td><td>2.0</td></tr><tr><td> 2 Series</td><td>2018</td><td>16250</td><td>Manual</td><td>10401</td><td>Petrol</td><td>145</td><td>52.3</td><td>1.5</td></tr><tr><td> 4 Series</td><td>2017</td><td>14250</td><td>Manual</td><td>42668</td><td>Diesel</td><td>30</td><td>62.8</td><td>2.0</td></tr><tr><td> 5 Series</td><td>2016</td><td>14250</td><td>Automatic</td><td>36099</td><td>Diesel</td><td>20</td><td>68.9</td><td>2.0</td></tr><tr><td> X3</td><td>2017</td><td>15500</td><td>Manual</td><td>74907</td><td>Diesel</td><td>145</td><td>52.3</td><td>2.0</td></tr><tr><td> 1 Series</td><td>2017</td><td>11800</td><td>Manual</td><td>29840</td><td>Diesel</td><td>20</td><td>68.9</td><td>2.0</td></tr><tr><td> X3</td><td>2016</td><td>15500</td><td>Automatic</td><td>77823</td><td>Diesel</td><td>125</td><td>54.3</td><td>2.0</td></tr><tr><td> 2 Series</td><td>2015</td><td>10500</td><td>Manual</td><td>31469</td><td>Diesel</td><td>20</td><td>68.9</td><td>2.0</td></tr><tr><td> X3</td><td>2017</td><td>22000</td><td>Automatic</td><td>19057</td><td>Diesel</td><td>145</td><td>54.3</td><td>2.0</td></tr><tr><td> 3 Series</td><td>2017</td><td>16500</td><td>Manual</td><td>16570</td><td>Diesel</td><td>125</td><td>58.9</td><td>2.0</td></tr><tr><td> 3 Series</td><td>2017</td><td>14250</td><td>Automatic</td><td>55594</td><td>Other</td><td>135</td><td>148.7</td><td>2.0</td></tr><tr><td> 3 Series</td><td>2017</td><td>16000</td><td>Automatic</td><td>45456</td><td>Diesel</td><td>30</td><td>64.2</td><td>2.0</td></tr><tr><td> 1 Series</td><td>2017</td><td>15500</td><td>Automatic</td><td>22812</td><td>Diesel</td><td>20</td><td>68.9</td><td>1.5</td></tr><tr><td> 4 Series</td><td>2014</td><td>14000</td><td>Automatic</td><td>47348</td><td>Diesel</td><td>125</td><td>60.1</td><td>2.0</td></tr><tr><td> 1 Series</td><td>2015</td><td>9700</td><td>Automatic</td><td>75124</td><td>Diesel</td><td>20</td><td>70.6</td><td>2.0</td></tr><tr><td> 3 Series</td><td>2015</td><td>12600</td><td>Automatic</td><td>78957</td><td>Diesel</td><td>30</td><td>62.8</td><td>2.0</td></tr><tr><td> 3 Series</td><td>2016</td><td>15100</td><td>Automatic</td><td>29213</td><td>Diesel</td><td>30</td><td>64.2</td><td>2.0</td></tr><tr><td> 1 Series</td><td>2016</td><td>9400</td><td>Manual</td><td>44498</td><td>Diesel</td><td>0</td><td>83.1</td><td>1.5</td></tr><tr><td> 1 Series</td><td>2016</td><td>14300</td><td>Automatic</td><td>22461</td><td>Diesel</td><td>20</td><td>67.3</td><td>2.0</td></tr><tr><td> 1 Series</td><td>2016</td><td>11200</td><td>Manual</td><td>23005</td><td>Petrol</td><td>125</td><td>53.3</td><td>1.5</td></tr><tr><td> 3 Series</td><td>2019</td><td>17800</td><td>Automatic</td><td>22310</td><td>Diesel</td><td>145</td><td>64.2</td><td>2.0</td></tr><tr><td> 3 Series</td><td>2016</td><td>14400</td><td>Auto ...

# %% [markdown]
# Creating a dataframe with header is true

# %%
# printing the schema of the data
data = spark.read.csv(
    '/mnt/tf-abfss/data/ds/pyspark/bmw.csv',
    sep = ',',
    header = True,
    )

data.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- model: string (nullable = true)
# -- year: string (nullable = true)
# -- price: string (nullable = true)
# -- transmission: string (nullable = true)
# -- mileage: string (nullable = true)
# -- fuelType: string (nullable = true)
# -- tax: string (nullable = true)
# -- mpg: string (nullable = true)
# -- engineSize: string (nullable = true)
#
# </div>

# %%
# checking the data types
data.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[35]: [(&#39;model&#39;, &#39;string&#39;),
#  (&#39;year&#39;, &#39;string&#39;),
#  (&#39;price&#39;, &#39;string&#39;),
#  (&#39;transmission&#39;, &#39;string&#39;),
#  (&#39;mileage&#39;, &#39;string&#39;),
#  (&#39;fuelType&#39;, &#39;string&#39;),
#  (&#39;tax&#39;, &#39;string&#39;),
#  (&#39;mpg&#39;, &#39;string&#39;),
#  (&#39;engineSize&#39;, &#39;string&#39;)]</div>

# %%
# getting the first 3 rows of data from spark dataframe
data.head(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[36]: [Row(model=&#39; 5 Series&#39;, year=&#39;2014&#39;, price=&#39;11200&#39;, transmission=&#39;Automatic&#39;, mileage=&#39;67068&#39;, fuelType=&#39;Diesel&#39;, tax=&#39;125&#39;, mpg=&#39;57.6&#39;, engineSize=&#39;2.0&#39;),
#  Row(model=&#39; 6 Series&#39;, year=&#39;2018&#39;, price=&#39;27000&#39;, transmission=&#39;Automatic&#39;, mileage=&#39;14827&#39;, fuelType=&#39;Petrol&#39;, tax=&#39;145&#39;, mpg=&#39;42.8&#39;, engineSize=&#39;2.0&#39;),
#  Row(model=&#39; 5 Series&#39;, year=&#39;2016&#39;, price=&#39;16000&#39;, transmission=&#39;Automatic&#39;, mileage=&#39;62794&#39;, fuelType=&#39;Diesel&#39;, tax=&#39;160&#39;, mpg=&#39;51.4&#39;, engineSize=&#39;3.0&#39;)]</div>

# %%
data.show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+----+-----+------------+-------+--------+---+----+----------+
#     model|year|price|transmission|mileage|fuelType|tax| mpg|engineSize|
# +---------+----+-----+------------+-------+--------+---+----+----------+
#  5 Series|2014|11200|   Automatic|  67068|  Diesel|125|57.6|       2.0|
#  6 Series|2018|27000|   Automatic|  14827|  Petrol|145|42.8|       2.0|
# +---------+----+-----+------------+-------+--------+---+----+----------+
# only showing top 2 rows
#
# </div>

# %%
data.first()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[38]: Row(model=&#39; 5 Series&#39;, year=&#39;2014&#39;, price=&#39;11200&#39;, transmission=&#39;Automatic&#39;, mileage=&#39;67068&#39;, fuelType=&#39;Diesel&#39;, tax=&#39;125&#39;, mpg=&#39;57.6&#39;, engineSize=&#39;2.0&#39;)</div>

# %%
data.describe().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+---------+-----------------+------------------+------------+------------------+--------+------------------+-----------------+-----------------+
# summary|    model|             year|             price|transmission|           mileage|fuelType|               tax|              mpg|       engineSize|
# +-------+---------+-----------------+------------------+------------+------------------+--------+------------------+-----------------+-----------------+
#   count|    10781|            10781|             10781|       10781|             10781|   10781|             10781|            10781|            10781|
#    mean|     null|2017.078935163714|   22733.408867452|        null|25496.986550412763|    null|131.70206845376126|56.39903533995112|2.167767368518684|
#  stddev|     null|2.349038136071664|11415.528189035651|        null|25143.192559298022|    null| 61.51075523545254| 31.3369578703552|0.552053777239839|
#     min| 1 Series|             1996|             10000|   Automatic|                 1|  Diesel|                 0|            113.0|              0.0|
#     max|       i8|             2020|              9999|   Semi-Auto|              9998|  Petrol|               580|             85.6|              6.6|
# +-------+---------+-----------------+------------------+------------+------------------+--------+------------------+-----------------+-----------------+
#
# </div>

# %%
data.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[40]: [&#39;model&#39;,
#  &#39;year&#39;,
#  &#39;price&#39;,
#  &#39;transmission&#39;,
#  &#39;mileage&#39;,
#  &#39;fuelType&#39;,
#  &#39;tax&#39;,
#  &#39;mpg&#39;,
#  &#39;engineSize&#39;]</div>

# %%
data.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[41]: 10781</div>

# %% [markdown]
# Creating a new column as stock_Date with the reference of Date column

# %%
data = data.withColumn('Year_of_purchase', data.year)

data.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+----+-----+------------+-------+--------+---+----+----------+----------------+
#     model|year|price|transmission|mileage|fuelType|tax| mpg|engineSize|Year_of_purchase|
# +---------+----+-----+------------+-------+--------+---+----+----------+----------------+
#  5 Series|2014|11200|   Automatic|  67068|  Diesel|125|57.6|       2.0|            2014|
#  6 Series|2018|27000|   Automatic|  14827|  Petrol|145|42.8|       2.0|            2018|
#  5 Series|2016|16000|   Automatic|  62794|  Diesel|160|51.4|       3.0|            2016|
#  1 Series|2017|12750|   Automatic|  26676|  Diesel|145|72.4|       1.5|            2017|
#  7 Series|2014|14500|   Automatic|  39554|  Diesel|160|50.4|       3.0|            2014|
# +---------+----+-----+------------+-------+--------+---+----+----------+----------------+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# Renaming the column

# %%
data = data.withColumnRenamed('Year_of_purchase', 'year_of_purchase')

data.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+----+-----+------------+-------+--------+---+----+----------+----------------+
#     model|year|price|transmission|mileage|fuelType|tax| mpg|engineSize|year_of_purchase|
# +---------+----+-----+------------+-------+--------+---+----+----------+----------------+
#  5 Series|2014|11200|   Automatic|  67068|  Diesel|125|57.6|       2.0|            2014|
#  6 Series|2018|27000|   Automatic|  14827|  Petrol|145|42.8|       2.0|            2018|
#  5 Series|2016|16000|   Automatic|  62794|  Diesel|160|51.4|       3.0|            2016|
#  1 Series|2017|12750|   Automatic|  26676|  Diesel|145|72.4|       1.5|            2017|
#  7 Series|2014|14500|   Automatic|  39554|  Diesel|160|50.4|       3.0|            2014|
# +---------+----+-----+------------+-------+--------+---+----+----------+----------------+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# Dropping the extra created colun from the spark dataframe

# %%
# after dropping the added column we are having the existing columns
data = data.drop('year_of_purchas')

data.show(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+----+-----+------------+-------+--------+---+----+----------+----------------+
#     model|year|price|transmission|mileage|fuelType|tax| mpg|engineSize|year_of_purchase|
# +---------+----+-----+------------+-------+--------+---+----+----------+----------------+
#  5 Series|2014|11200|   Automatic|  67068|  Diesel|125|57.6|       2.0|            2014|
#  6 Series|2018|27000|   Automatic|  14827|  Petrol|145|42.8|       2.0|            2018|
#  5 Series|2016|16000|   Automatic|  62794|  Diesel|160|51.4|       3.0|            2016|
#  1 Series|2017|12750|   Automatic|  26676|  Diesel|145|72.4|       1.5|            2017|
#  7 Series|2014|14500|   Automatic|  39554|  Diesel|160|50.4|       3.0|            2014|
#  5 Series|2016|14900|   Automatic|  35309|  Diesel|125|60.1|       2.0|            2016|
#  5 Series|2017|16000|   Automatic|  38538|  Diesel|125|60.1|       2.0|            2017|
#  2 Series|2018|16250|      Manual|  10401|  Petrol|145|52.3|       1.5|            2018|
#  4 Series|2017|14250|      Manual|  42668|  Diesel| 30|62.8|       2.0|            2017|
#  5 Series|2016|14250|   Automatic|  36099|  Diesel| 20|68.9|       2.0|            2016|
# +---------+----+-----+------------+-------+--------+---+----+----------+----------------+
# only showing top 10 rows
#
# </div>

# %%
##threshold
data.na.drop(how="any",thresh=3).show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+----+-----+------------+-------+--------+---+----+----------+----------------+
#     model|year|price|transmission|mileage|fuelType|tax| mpg|engineSize|year_of_purchase|
# +---------+----+-----+------------+-------+--------+---+----+----------+----------------+
#  5 Series|2014|11200|   Automatic|  67068|  Diesel|125|57.6|       2.0|            2014|
#  6 Series|2018|27000|   Automatic|  14827|  Petrol|145|42.8|       2.0|            2018|
# +---------+----+-----+------------+-------+--------+---+----+----------+----------------+
# only showing top 2 rows
#
# </div>

# %%
from pyspark.sql.functions import col, lit
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# checking the null values

# %%
data.filter(col("price").isNull()).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+----+-----+------------+-------+--------+---+---+----------+----------------+
# model|year|price|transmission|mileage|fuelType|tax|mpg|engineSize|year_of_purchase|
# +-----+----+-----+------------+-------+--------+---+---+----------+----------------+
# +-----+----+-----+------------+-------+--------+---+---+----------+----------------+
#
# </div>

# %% [markdown]
# Imputting the missing values

# %%
# Remove Rows with Missing Values

data.na.drop()
data.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+----+-----+------------+-------+--------+---+----+----------+----------------+
#     model|year|price|transmission|mileage|fuelType|tax| mpg|engineSize|year_of_purchase|
# +---------+----+-----+------------+-------+--------+---+----+----------+----------------+
#  5 Series|2014|11200|   Automatic|  67068|  Diesel|125|57.6|       2.0|            2014|
#  6 Series|2018|27000|   Automatic|  14827|  Petrol|145|42.8|       2.0|            2018|
#  5 Series|2016|16000|   Automatic|  62794|  Diesel|160|51.4|       3.0|            2016|
#  1 Series|2017|12750|   Automatic|  26676|  Diesel|145|72.4|       1.5|            2017|
#  7 Series|2014|14500|   Automatic|  39554|  Diesel|160|50.4|       3.0|            2014|
# +---------+----+-----+------------+-------+--------+---+----+----------+----------------+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# Selecting the single column and multiple column

# %%
## Selecting Single Column

data.select('mileage').show(5)

## Selecting Multiple columns

data.select(['fuelType','mileage', 'mpg', 'engineSize']).show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+
# mileage|
# +-------+
#   67068|
#   14827|
#   62794|
#   26676|
#   39554|
# +-------+
# only showing top 5 rows
#
# +--------+-------+----+----------+
# fuelType|mileage| mpg|engineSize|
# +--------+-------+----+----------+
#   Diesel|  67068|57.6|       2.0|
#   Petrol|  14827|42.8|       2.0|
#   Diesel|  62794|51.4|       3.0|
#   Diesel|  26676|72.4|       1.5|
#   Diesel|  39554|50.4|       3.0|
# +--------+-------+----+----------+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# filtering the column

# %%
from pyspark.sql.functions import col, lit

data.filter((col('mpg') >= lit(20)) | (col('mpg') <= lit(45))).show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+----+-----+------------+-------+--------+---+----+----------+----------------+
#     model|year|price|transmission|mileage|fuelType|tax| mpg|engineSize|year_of_purchase|
# +---------+----+-----+------------+-------+--------+---+----+----------+----------------+
#  5 Series|2014|11200|   Automatic|  67068|  Diesel|125|57.6|       2.0|            2014|
#  6 Series|2018|27000|   Automatic|  14827|  Petrol|145|42.8|       2.0|            2018|
#  5 Series|2016|16000|   Automatic|  62794|  Diesel|160|51.4|       3.0|            2016|
#  1 Series|2017|12750|   Automatic|  26676|  Diesel|145|72.4|       1.5|            2017|
#  7 Series|2014|14500|   Automatic|  39554|  Diesel|160|50.4|       3.0|            2014|
# +---------+----+-----+------------+-------+--------+---+----+----------+----------------+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# filtering the data by using the between condition

# %%
## fetch the data where the adjusted value is between 100.0 and 500.0

data.filter(data.year.between(2016, 2019)).show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+----+-----+------------+-------+--------+---+----+----------+----------------+
#     model|year|price|transmission|mileage|fuelType|tax| mpg|engineSize|year_of_purchase|
# +---------+----+-----+------------+-------+--------+---+----+----------+----------------+
#  6 Series|2018|27000|   Automatic|  14827|  Petrol|145|42.8|       2.0|            2018|
#  5 Series|2016|16000|   Automatic|  62794|  Diesel|160|51.4|       3.0|            2016|
# +---------+----+-----+------------+-------+--------+---+----+----------+----------------+
# only showing top 2 rows
#
# </div>

# %% [markdown]
# filtering the data by using the When condition

# %%
from pyspark.sql import functions as f
data.select('model', 'price','transmission', 
            f.when(data.engineSize >= 2.0, 1).otherwise(0)
           ).show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+-----+------------+-----------------------------------------------+
#     model|price|transmission|CASE WHEN (engineSize &gt;= 2.0) THEN 1 ELSE 0 END|
# +---------+-----+------------+-----------------------------------------------+
#  5 Series|11200|   Automatic|                                              1|
#  6 Series|27000|   Automatic|                                              1|
#  5 Series|16000|   Automatic|                                              1|
#  1 Series|12750|   Automatic|                                              0|
#  7 Series|14500|   Automatic|                                              1|
# +---------+-----+------------+-----------------------------------------------+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# filtering the data by using the like condition

# %%
data.select('model','engineSize', 
            data.engineSize.rlike('^[3]').alias('Engine size that with 3')
            ).distinct().show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+----------+-----------------------+
#     model|engineSize|Engine size that with 3|
# +---------+----------+-----------------------+
#  2 Series|       1.5|                  false|
#  7 Series|       3.0|                   true|
#  5 Series|       2.0|                  false|
#  1 Series|       1.5|                  false|
#  5 Series|       3.0|                   true|
# +---------+----------+-----------------------+
# only showing top 5 rows
#
# </div>
